# %% [markdown]
# **WEEK 1: Introduction to Machine Learning**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Import the libraries needed for this project

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import load_iris

# %% [markdown]
# Load the Iris dataset

# %%
# Load the dataset

iris = load_iris()

# Convert to a pandas DataFrame

df = pd.DataFrame(iris.data, columns=iris.feature_names)

# Add the target column

df["species"] = iris.target

# Replace numbers with flower names

df["species"] = df["species"].replace({
    0: "Setosa",
    1: "Versicolor",
    2: "Virginica"
})

# Display first five rows

df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  Setosa
# 1  Setosa
# 2  Setosa
# 3  Setosa
# 4  Setosa

# %% [markdown]
# Display dataset information

# %%
# Number of rows and columns

print("Dataset Shape:")
print(df.shape)

print("\n")

# Column names

print("Column Names:")
print(df.columns)

print("\n")

# Data types

print("Data Types:")
print(df.dtypes)
# Out:
# Dataset Shape:
# (150, 5)
#
#
# Column Names:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'species'],
#       dtype='object')
#
#
# Data Types:
# sepal length (cm)    float64
# sepal width (cm)     float64
# petal length (cm)    float64
# petal width (cm)     float64
# species               object
# dtype: object

# %% [markdown]
# Display summary statistics

# %%
# Summary statistics

df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %% [markdown]
# Identify features and target variable

# %%
# Features

X = df.drop("species", axis=1)

# Target

y = df["species"]

print("Features")
print(X.head())

print("\nTarget")
print(y.head())
# Out:
# Features
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
# Target
# 0    Setosa
# 1    Setosa
# 2    Setosa
# 3    Setosa
# 4    Setosa
# Name: species, dtype: object

# %% [markdown]
# Visualize the data: Histogram

# %%
df.hist(figsize=(10,8))
plt.show()

# %% [markdown]
# Scatter Plot

# %%
plt.figure(figsize=(8,6))

sns.scatterplot(
    data=df,
    x="sepal length (cm)",
    y="petal length (cm)",
    hue="species"
)

plt.title("Sepal Length vs Petal Length")
plt.show()

# %% [markdown]
# Pairplot

# %%
sns.pairplot(df, hue="species")
plt.show()

# %% [markdown]
# Conclusion
#
# The Iris dataset contains measurements of three different flower species.
#
# The features are:
#
# • Sepal Length
# • Sepal Width
# • Petal Length
# • Petal Width
#
# The target variable is Species.
#
# This dataset can be used to build a machine learning model that predicts the species of a flower based on its measurements.

# %% [markdown]
# Load the Titanic Dataset

# %%
# Load Titanic dataset

df = sns.load_dataset("titanic")

# Display first five rows

df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# Display Dataset Shape

# %%
print("Rows and Columns")

print(df.shape)
# Out:
# Rows and Columns
# (891, 15)

# %% [markdown]
# Display Dataset Information:
# - Number of rows
# - Number of columns
# - Missing values
# - Data types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %% [markdown]
# View Column names

# %%
print(df.columns)
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %% [markdown]
# Display Summary Statistics

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# Identify Features and Target Variable: Goal is to predict whether a passenger survived.

# %%
# Features

X = df.drop("survived", axis=1)

# Target

y = df["survived"]

print("Features")

print(X.head())

print()

print("Target")

print(y.head())
# Out:
# Features
#    pclass     sex   age  sibsp  parch     fare embarked  class    who  \
# 0       3    male  22.0      1      0   7.2500        S  Third    man
# 1       1  female  38.0      1      0  71.2833        C  First  woman
# 2       3  female  26.0      0      0   7.9250        S  Third  woman
# 3       1  female  35.0      1      0  53.1000        S  First  woman
# 4       3    male  35.0      0      0   8.0500        S  Third    man
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False
# 1       False    C    Cherbourg   yes  False
# 2       False  NaN  Southampton   yes   True
# 3       False    C  Southampton   yes  False
# 4        True  NaN  Southampton    no   True
#
# Target
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: survived, dtype: int64

# %% [markdown]
# Check the Target Variable

# %%
df["survived"].value_counts()
# Out:
# survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %% [markdown]
# Visualize Survival Counts

# %%
plt.figure(figsize=(6,5))

sns.countplot(data=df, x="survived")

plt.title("Passengers Who Survived")

plt.xlabel("Survived")

plt.ylabel("Number of Passengers")

plt.show()

# %% [markdown]
# Survival by Gender

# %%
plt.figure(figsize=(6,5))

sns.countplot(data=df,
              x="sex",
              hue="survived")

plt.title("Survival by Gender")

plt.show()

# %% [markdown]
# Passenger Class Distribution

# %%
plt.figure(figsize=(6,5))

sns.countplot(data=df,
              x="class")

plt.title("Passenger Classes")

plt.show()

# %% [markdown]
# Age Distribution

# %%
plt.figure(figsize=(8,5))

sns.histplot(df["age"], bins=30)

plt.title("Passenger Age Distribution")

plt.show()

# %% [markdown]
# Correlation Heatmap

# %%
plt.figure(figsize=(10,8))

numeric_df = df.select_dtypes(include=np.number)

sns.heatmap(
    numeric_df.corr(),
    annot=True,
    cmap="coolwarm"
)

plt.show()

# %% [markdown]
# # Conclusion
#
# The Titanic dataset contains information about passengers aboard the RMS Titanic.
#
# The target variable is:
#
# • survived
#
# The features include:
#
# • age
# • sex
# • passenger class
# • fare
# • family size
# • port of embarkation
#
# This dataset can be used to build a machine learning model that predicts whether a passenger survived based on their characteristics.
#
# From the visualizations, females generally had a higher survival rate than males, and first-class passengers had a better chance of survival than passengers in lower classes.
